# %% [markdown]
# # 05 — Naive Bayes (Triple Pipeline)
#
# This notebook trains **Naive Bayes** on three datasets:
# 1. **Standard**: Basic cleaning.
# 2. **Irony-Augmented**: With `[IRONIA]` tags.
# 3. **Obfuscated**: Standard + entity obfuscation.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import joblib
import os

# Corpus Configuration
CORPUS_NAME = 'raw_corpus' # Options: 'pre-filtered-corpus', 'raw_corpus'
PROCESSED_DATA_DIR = f'../data/processed/{CORPUS_NAME}'
MODELS_DIR_BASE = f'../models/{CORPUS_NAME}'


plt.style.use('../style.mplstyle')

# %%
# %load_ext watermark
# %watermark -v -n -m -p numpy,pandas,sklearn,matplotlib,seaborn,joblib
# Out:
# Python implementation: CPython
# Python version       : 3.13.0
# IPython version      : 9.10.0
#
# numpy     : 2.4.2
# pandas    : 3.0.0
# sklearn   : 1.8.0
# matplotlib: 3.10.8
# seaborn   : 0.13.2
# joblib    : 1.5.3
#
# Compiler    : Clang 16.0.0 (clang-1600.0.26.4)
# OS          : Darwin
# Release     : 25.2.0
# Machine     : x86_64
# Processor   : i386
# CPU cores   : 8
# Architecture: 64bit

# %% [markdown]
# ## Pipeline Function

# %%
# Corpus Configuration
CORPUS_NAME = 'pre-filtered-corpus' # Options: 'pre-filtered-corpus', 'raw_corpus'
PROCESSED_DATA_DIR = f'../data/processed/{CORPUS_NAME}'
MODELS_DIR_BASE = f'../models/{CORPUS_NAME}'

MODEL_NAME = "Naive Bayes"

def run_pipeline(variation_name, input_dir, output_dir):
    print(f"\n{'='*20} {MODEL_NAME}: {variation_name} {'='*20}")
    
    # 1. Load Data
    train_df = pd.read_csv(f'{input_dir}/train.csv')
    test_df = pd.read_csv(f'{input_dir}/test.csv')
    train_df['text_clean'] = train_df['text_clean'].fillna('')
    test_df['text_clean'] = test_df['text_clean'].fillna('')
    
    # 2. Vectorize
    vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 2))
    X_train = vectorizer.fit_transform(train_df['text_clean'])
    X_test = vectorizer.transform(test_df['text_clean'])
    y_train = train_df['label']
    y_test = test_df['label']
    
    # 3. Train
    clf = MultinomialNB()
    clf.fit(X_train, y_train)
    
    # 4. Evaluate
    y_pred = clf.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    print(f"{MODEL_NAME} ({variation_name}) Accuracy: {acc:.4f}")
    print(classification_report(y_test, y_pred))
    
    # 5. Export
    os.makedirs(output_dir, exist_ok=True)
    joblib.dump(clf, f'{output_dir}/model.joblib')
    joblib.dump(vectorizer, f'{output_dir}/vectorizer.joblib')
    print(f"Artifacts saved to {output_dir}")
    
    return acc

# %% [markdown]
# ## Run All Pipelines

# %%
    acc_standard = run_pipeline("Standard", f"{PROCESSED_DATA_DIR}/standard", f"{MODELS_DIR_BASE}/naive_bayes/standard")
    acc_irony = run_pipeline("Irony", f"{PROCESSED_DATA_DIR}/irony", f"{MODELS_DIR_BASE}/naive_bayes/irony")
    acc_obfuscated = run_pipeline("Obfuscated", f"{PROCESSED_DATA_DIR}/obfuscated", f"{MODELS_DIR_BASE}/naive_bayes/obfuscated")
# Out:
# ==================== Naive Bayes: Standard ====================
# Naive Bayes (Standard) Accuracy: 0.8378
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.85      0.83      0.84       225
#     POSITIVE       0.83      0.85      0.84       225
#
#     accuracy                           0.84       450
#    macro avg       0.84      0.84      0.84       450
# weighted avg       0.84      0.84      0.84       450
# Artifacts saved to ../models/pre-filtered-corpus/naive_bayes/standard
#
# ==================== Naive Bayes: Irony ====================
# Naive Bayes (Irony) Accuracy: 0.8333
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.84      0.82      0.83       225
#     POSITIVE       0.83      0.84      0.84       225
#
#     accuracy                           0.83       450
#    macro avg       0.83      0.83      0.83       450
# weighted avg       0.83      0.83      0.83       450
# ...

# %% [markdown]
# ## Comparison

# %%
print("\n=== Final Comparison ===")
print(f"Standard: {acc_standard:.4f}")
print(f"Irony:    {acc_irony:.4f}")
print(f"Obfuscated: {acc_obfuscated:.4f}")
diff = acc_irony - acc_standard
print(f"Impact of Irony features: {diff:+.4f}")
# Out:
# === Final Comparison ===
# Standard: 0.8378
# Irony:    0.8333
# Obfuscated: 0.8311
# Impact of Irony features: -0.0044
